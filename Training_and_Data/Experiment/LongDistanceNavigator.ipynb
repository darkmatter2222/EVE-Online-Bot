# %%
import json, time
import pyautogui
import socket, uuid, time
import mss
import mss.tools
import tensorflow as tf
from PIL import Image, ImageDraw
import cv2
import numpy as np
import sys, os, decimal, json
sys.path.append(os.path.realpath('..'))
from MiningBot.EveInterface.Interface import Interface, get_cells, get_row_points, get_col_points
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import json, time
# ----> 2 import pyautogui
#       3 import socket, uuid, time
#       4 import mss
#
# ModuleNotFoundError: No module named 'pyautogui'

# %%
config_dir = r'../MiningBot/Configs/configs.json'
config = json.load(open(config_dir))[socket.gethostname()]
game = Interface(config_dir=config_dir)

# %%
classifiers = {}

for clsf_name in config['Classifiers'].keys():
    f = open(config['Classifiers'][clsf_name]['class_location'], "r")
    classifiers[clsf_name] = {
        'model': tf.keras.models.load_model(config['Classifiers'][clsf_name]['model_location']),
        'classes': json.loads(f.read()),
        'image_resize': tuple(config['Classifiers'][clsf_name]['image_resize']),
        'save_images': bool(config['Classifiers'][clsf_name]['save_images']),
    }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 classifiers = {}
# ----> 3 for clsf_name in config['Classifiers'].keys():
#       4     f = open(config['Classifiers'][clsf_name]['class_location'], "r")
#       5     classifiers[clsf_name] = {
#       6         'model': tf.keras.models.load_model(config['Classifiers'][clsf_name]['model_location']),
#       7         'classes': json.loads(f.read()),
#       8         'image_resize': tuple(config['Classifiers'][clsf_name]['image_resize']),
#       9         'save_images': bool(config['Classifiers'][clsf_name]['save_images']),
#      10     }
#
# NameError: name 'config' is not defined

# %%
def get_screen():
    with mss.mss() as sct:
        mon = sct.monitors[config['monitor_number']]

        # The screen part to capture
        monitor = {
            "top": mon["top"],
            "left": mon["left"],
            "width": mon["width"],
            "height": mon["height"],
            "mon": config['monitor_number'],
        }

        # Grab the data
        img = np.array(sct.grab(monitor))
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img = Image.fromarray(img)
        return img

# %%
def execute_clsf(img, clsf_name):
    img = img.resize(
        (classifiers[clsf_name]['image_resize'][1], classifiers[clsf_name]['image_resize'][0]),
        # TF trains backwards
        resample=Image.Resampling.NEAREST)
    img_array = tf.keras.utils.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Create a batch

    predictions = classifiers[clsf_name]['model'].predict(img_array)
    scores = tf.nn.softmax(predictions[0])
    result = {
        'argmax_index': np.argmax(scores),
        'value_at_argmax': scores[np.argmax(scores)].numpy(),
        'pass_general_tollerance': scores[np.argmax(scores)].numpy() > 0.5,
        'class': classifiers[clsf_name]['classes'][np.argmax(scores)],
        'classes': classifiers[clsf_name]['classes'],
        'scores': scores.numpy().tolist()
    }
    return result

# %%
def get_processed_cords(x, y):
    return x + config['monitor_offset_x'], y + config['monitor_offset_y']

# %%
while True:
    while True:
        send_home = False
        
        pyautogui.moveTo(get_processed_cords(1283, 133))
        time.sleep(0.1)
        pyautogui.click(button='left')
        time.sleep(2)       
        search_df = game.get_search_data(rows=13, refresh_screen=True)
        search_df = search_df[(~search_df['Name'].str.contains('Jita')) & (~search_df['Name'].str.contains('Amsen'))].reset_index()
        del search_df['index']
        click_target = search_df.loc[0, 'click_target']
        pyautogui.moveTo(click_target)
        time.sleep(0.1)
        pyautogui.click(button='right')
        time.sleep(0.1)
        box_top_left = (935,204)
        box_bottom_right = (1200,600)
        img = get_screen()
        img = img.crop([box_top_left[0], box_top_left[1], box_bottom_right[0], box_bottom_right[1]])
        img.save(f'O:\\source\\repos\\EVE-Online-Bot\\training_data\\unclass\\{uuid.uuid1()}.png')
        
        dest_result = execute_clsf(img, 'set_dest')
        print(dest_result)
        
        if dest_result['class'] == 'second_pos':
            pyautogui.moveTo(click_target[0] + 50, click_target[1] + 60)
        elif dest_result['class'] == 'seventh_pos':
            pyautogui.moveTo(click_target[0] + 50, click_target[1] + 234)
        elif dest_result['class'] == 'third_pos':
            pyautogui.moveTo(click_target[0] + 50, click_target[1] + 109)

        time.sleep(0.1)
        pyautogui.click(button='left')
        time.sleep(1)

        nav_point_xy = get_processed_cords(137, 378)
        while True:
            pyautogui.moveTo(nav_point_xy)
            time.sleep(0.1)
            pyautogui.click(button='right')
            time.sleep(0.1)
            box = (102, 289, 458, 658)
            img = get_screen()
            state_result = execute_clsf(img, 'game_state')
            print(state_result)
            img = img.crop(box)
            print('saving...')
            img.save(f'O:\\source\\repos\\EVE-Online-Bot\\training_data\\unclass\\{uuid.uuid1()}.png')
            nav_result = execute_clsf(img, 'nav_options')
            print(nav_result)
            if state_result['class'] == 'in_flight':
                if nav_result['class'] == 'dock_now':
                    print('Docking Now...')
                    pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 75)
                    time.sleep(0.1)
                    pyautogui.click(button='left')
                elif nav_result['class'] == 'jump_though_first':
                    print('jumping fist pos...')
                    pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 25)
                    time.sleep(0.1)
                    pyautogui.click(button='left')
                elif nav_result['class'] == 'jump_through_second':
                    print('jumping second pos...')
                    pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 50)
                    time.sleep(0.1)
                    pyautogui.click(button='left')
                elif nav_result['class'] == 'warp_to_dock':
                    print('Warp To Dock pos...')
                    pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 75)
                    time.sleep(0.1)
                    pyautogui.click(button='left')
                else:
                    print('do nothing nav...')
            elif state_result['class'] == 'in_hanger':
                time.sleep(2)

                pyautogui.moveTo(get_processed_cords(*config['hanger_target']))  # ensure we have mining hold selected
                time.sleep(0.1)
                pyautogui.click(button='left')
                time.sleep(1)


                pyautogui.moveTo(get_processed_cords(*config['click_and_drag_inv_box'][2:4]))  #
                time.sleep(0.1)
                x, y = get_processed_cords(*config['click_and_drag_inv_box'][0:2])
                pyautogui.dragTo(x, y, 1, button='left')
                time.sleep(0.1)
                pyautogui.moveTo(get_processed_cords(*config['Load_to_mininghold_click_and_drag_inv_line'][0:2]))
                time.sleep(0.1)
                x, y = get_processed_cords(*config['Load_to_mininghold_click_and_drag_inv_line'][2:4])
                pyautogui.dragTo(x, y, 1, button='left')


                time.sleep(2)

                img = get_screen()
                menu_result = execute_clsf(img, 'hanger_menus')
                print(menu_result)
                if menu_result['class'] == 'set_quant':
                    pyautogui.moveTo(get_processed_cords(*config['set_quant_target']))  # ensure we have mining hold selected
                    time.sleep(0.1)
                    pyautogui.click(button='left')
                    time.sleep(1)
                    send_home = True

                time.sleep(0.1)
                pyautogui.moveTo(get_processed_cords(*config['exit_hanger_target']))
                time.sleep(0.1)
                pyautogui.click(button='left')
                time.sleep(30)
                break
            else:
                print('do nothing state...')
            time.sleep(0.1)
            pyautogui.moveTo(get_processed_cords(100, 100))
            time.sleep(0.1)
            pyautogui.click(button='left')
            time.sleep(10)
        if send_home:
            break


    search_df = game.get_search_data(rows=13, refresh_screen=True)
    search_df = search_df[search_df['Name'].str.contains('Jita')].reset_index()
    del search_df['index']
    click_target = search_df.loc[0, 'click_target']
    pyautogui.moveTo(click_target)
    time.sleep(0.1)
    pyautogui.click(button='right')
    time.sleep(0.1)
    pyautogui.moveTo(click_target[0] + 50, click_target[1] + 60)
    time.sleep(0.1)
    pyautogui.click(button='left')
    time.sleep(1)         

    nav_point_xy = get_processed_cords(137, 378)
    while True:
        pyautogui.moveTo(nav_point_xy)
        time.sleep(0.1)
        pyautogui.click(button='right')
        time.sleep(0.1)
        box = (102, 289, 458, 658)
        img = get_screen()
        state_result = execute_clsf(img, 'game_state')
        print(state_result)
        img = img.crop(box)
        nav_result = execute_clsf(img, 'nav_options')
        img.save(f'O:\\source\\repos\\EVE-Online-Bot\\training_data\\unclass\\{uuid.uuid1()}.png')
        print(nav_result)
        if state_result['class'] == 'in_flight':
            if nav_result['class'] == 'dock_now':
                print('Docking Now...')
                pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 75)
                time.sleep(0.1)
                pyautogui.click(button='left')
            elif nav_result['class'] == 'jump_though_first':
                print('jumping fist pos...')
                pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 25)
                time.sleep(0.1)
                pyautogui.click(button='left')
            elif nav_result['class'] == 'jump_through_second':
                print('jumping second pos...')
                pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 50)
                time.sleep(0.1)
                pyautogui.click(button='left')
            elif nav_result['class'] == 'warp_to_dock':
                print('Warp To Dock pos...')
                pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 75)
                time.sleep(0.1)
                pyautogui.click(button='left')
            else:
                print('do nothing nav...')
        elif state_result['class'] == 'in_hanger':
            time.sleep(2)

            pyautogui.moveTo(get_processed_cords(*config['mining_hold_target']))  # ensure we have mining hold selected
            time.sleep(0.1)
            pyautogui.click(button='left')
            time.sleep(1)


            pyautogui.moveTo(get_processed_cords(*config['click_and_drag_inv_box'][2:4]))  #
            time.sleep(0.1)
            x, y = get_processed_cords(*config['click_and_drag_inv_box'][0:2])
            pyautogui.dragTo(x, y, 1, button='left')
            time.sleep(0.1)
            pyautogui.moveTo(get_processed_cords(*config['Unload_nav_bot_click_and_drag_inv_line'][0:2]))
            time.sleep(0.1)
            x, y = get_processed_cords(*config['Unload_nav_bot_click_and_drag_inv_line'][2:4])
            pyautogui.dragTo(x, y, 1, button='left')
            time.sleep(0.1)
            pyautogui.moveTo(get_processed_cords(*config['exit_hanger_target']))
            time.sleep(0.1)
            pyautogui.click(button='left')
            time.sleep(30)
            break
        else:
            print('do nothing state...')
        time.sleep(0.1)
        pyautogui.moveTo(get_processed_cords(100, 100))
        time.sleep(0.1)
        pyautogui.click(button='left')
        time.sleep(10)
# Out:
# 1/1 [==============================] - 0s 47ms/step
# {'argmax_index': 0, 'value_at_argmax': 0.9929731, 'pass_general_tollerance': True, 'class': 'second_pos', 'classes': ['second_pos', 'seventh_pos', 'third_pos'], 'scores': [0.9929730892181396, 0.0005673017585650086, 0.006459538359194994]}
# 1/1 [==============================] - 0s 61ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999968, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [1.6236298416849593e-10, 1.2359168593059633e-12, 0.9999967813491821, 3.2581651794316713e-06]}
# saving...
# 1/1 [==============================] - 0s 47ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock_3', 'warp_to_dock_4'], 'scores': [6.55214001544363e-14, 1.4499611635052784e-14, 1.0, 3.9930865146538264e-13, 5.10374366060511e-15, 3.2325496242984787e-15, 1.74911774212421e-17]}
# jumping fist pos...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 119
#     117     time.sleep(0.1)
#     118     pyautogui.click(button='left')
# --> 119     time.sleep(10)
#     120 if send_home:
#     121     break
#
# KeyboardInterrupt:

# %%
search_df = game.get_search_data(rows=13)
search_df = search_df[~search_df['Name'].str.contains('Jita')]
search_df
# Out:
#                       Name click_target
# 1     Itama Il = Perkone |  (-994, 244)
# 2        Itama VI ~ Moon 6  (-994, 274)
# 3       Itama VI ~ Perkone  (-994, 304)
# 4       Itama Vil ~ Maan 3  (-994, 334)
# 5       Itama Vil ~ Moan §  (-994, 364)
# 6      Itama Vil ~ Rapid A  (-994, 394)
# 7   Malkalen Iii ~ Ishukor  (-994, 424)
# 8       Malkalen 1V ~ Moon  (-994, 454)
# 9      Malkalen V ~ Moon 1  (-994, 484)
# 10    Veisto V - Caldari S  (-994, 514)
# 11      Veisto V - Moon 15  (-994, 544)

# %%
nav_point_xy = get_processed_cords(137, 378)
while True:
    pyautogui.moveTo(nav_point_xy)
    time.sleep(0.1)
    pyautogui.click(button='right')
    time.sleep(0.1)
    box = (102, 289, 458, 658)
    img = get_screen()
    state_result = execute_clsf(img, 'game_state')
    print(state_result)
    img = img.crop(box)
    nav_result = execute_clsf(img, 'nav_options')
    print(nav_result)
    if state_result['class'] == 'in_flight':
        if nav_result['class'] == 'dock_now':
            print('Docking Now...')
            pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 75)
            time.sleep(0.1)
            pyautogui.click(button='left')
        elif nav_result['class'] == 'jump_though_first':
            print('jumping fist pos...')
            pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 25)
            time.sleep(0.1)
            pyautogui.click(button='left')
        elif nav_result['class'] == 'jump_through_second':
            print('jumping second pos...')
            pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 50)
            time.sleep(0.1)
            pyautogui.click(button='left')
        elif nav_result['class'] == 'warp_to_dock':
            print('Warp To Dock pos...')
            pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 75)
            time.sleep(0.1)
            pyautogui.click(button='left')
        else:
            print('do nothing nav...')
    elif state_result['class'] == 'in_hanger':
        time.sleep(2)
        
        pyautogui.moveTo(get_processed_cords(*config['mining_hold_target']))  # ensure we have mining hold selected
        time.sleep(0.1)
        pyautogui.click(button='left')
        time.sleep(1)
        
        
        pyautogui.moveTo(get_processed_cords(*config['click_and_drag_inv_box'][2:4]))  #
        time.sleep(0.1)
        x, y = get_processed_cords(*config['click_and_drag_inv_box'][0:2])
        pyautogui.dragTo(x, y, 1, button='left')
        time.sleep(0.1)
        pyautogui.moveTo(get_processed_cords(*config['Unload_nav_bot_click_and_drag_inv_line'][0:2]))
        time.sleep(0.1)
        x, y = get_processed_cords(*config['Unload_nav_bot_click_and_drag_inv_line'][2:4])
        pyautogui.dragTo(x, y, 1, button='left')
        time.sleep(0.1)
        pyautogui.moveTo(get_processed_cords(*config['exit_hanger_target']))
        time.sleep(0.1)
        pyautogui.click(button='left')
    else:
        print('do nothing state...')
    time.sleep(0.1)
    pyautogui.moveTo(get_processed_cords(100, 100))
    time.sleep(0.1)
    pyautogui.click(button='left')
    time.sleep(10)
# Out:
# 1/1 [==============================] - 0s 87ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999999, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [3.529085118754438e-13, 2.2406818357668078e-14, 0.9999998807907104, 1.2652982661620626e-07]}
# 1/1 [==============================] - 0s 47ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.0941613608861939e-16, 1.4693961325473737e-11, 1.0, 2.1681695580259418e-16, 1.1860082270863013e-15, 1.1774707490768647e-14]}
# jumping fist pos...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999976, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [5.531049251418507e-13, 4.576486149136631e-14, 0.9999997615814209, 2.0417789414750587e-07]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [2.2442855268529893e-16, 1.8248742794657602e-11, 1.0, 3.759589353008306e-16, 2.6113553542981985e-15, 2.070510375564577e-14]}
# jumping fist pos...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999976, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [8.054662080543562e-13, 5.659339506356928e-14, 0.9999997615814209, 1.9368339110314992e-07]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [3.3386732705292267e-16, 1.9146783117318655e-11, 1.0, 6.539972620090383e-16, 3.991483098225333e-15, 3.73500634988453e-14]}
# jumping fist pos...
# 1/1 [==============================] - 0s 25ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999999, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [6.586148184987983e-13, 3.5578073961321094e-14, 0.9999998807907104, 1.428655167501347e-07]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [2.501275852445536e-16, 2.1102959657515186e-11, 1.0, 3.838848078767463e-16, 2.864306285644408e-15, 2.062162865869386e-14]}
# jumping fist pos...
# 1/1 [==============================] - 0s 23ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999857, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [2.765067905544094e-12, 4.3119882664477416e-12, 0.9999985694885254, 1.403449687131797e-06]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.0090730797600694e-17, 5.194395261143292e-13, 1.0, 1.1599438751725962e-17, 9.296056894195898e-17, 2.264349249214161e-15]}
# jumping fist pos...
# 1/1 [==============================] - 0s 23ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999987, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [6.781605832451021e-11, 1.943727839272269e-13, 0.9999986886978149, 1.3361476476347889e-06]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [2.2993443087038212e-12, 6.656135087546033e-10, 1.0, 3.433519541276055e-14, 4.285801713521664e-10, 7.958201805879916e-12]}
# jumping fist pos...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999958, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [2.410181221268459e-10, 3.6477759831829437e-13, 0.9999958276748657, 4.182617885817308e-06]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [3.1795989452465534e-12, 7.621768216559133e-10, 1.0, 3.3755072711581444e-14, 8.649205796018578e-10, 9.365882201739506e-12]}
# jumping fist pos...
# 1/1 [==============================] - 0s 25ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999969, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [8.858422329005577e-11, 2.4121251328799997e-13, 0.9999969005584717, 3.1291338018490933e-06]}
# 1/1 [==============================] - 0s 15ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.3616514599884555e-12, 4.742710668637073e-10, 1.0, 2.738505968757736e-14, 1.9895050884510823e-10, 5.301335759266834e-12]}
# jumping fist pos...
# 1/1 [==============================] - 0s 23ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999833, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [4.810271278521405e-11, 1.664563262617283e-13, 0.9999983310699463, 1.682221068222134e-06]}
# 1/1 [==============================] - 0s 13ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.17336468232615e-12, 4.4218140260454675e-10, 1.0, 2.781291635802624e-14, 1.552756395684085e-10, 4.841489622403605e-12]}
# jumping fist pos...
# 1/1 [==============================] - 0s 22ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999616, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [4.770055461733591e-09, 1.087073139838246e-10, 0.9999616146087646, 3.8327307265717536e-05]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [3.692276968178987e-16, 6.558185852018061e-12, 1.0, 6.486377139748459e-17, 5.122117075780476e-15, 5.728626123815972e-15]}
# jumping fist pos...
# 1/1 [==============================] - 0s 26ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999976, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [1.1242110622413856e-13, 2.5044951599802537e-14, 0.9999997615814209, 2.519815893720079e-07]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.073276704780455e-16, 9.014487940828264e-12, 1.0, 4.1380557175912464e-17, 4.770657906734486e-16, 5.605644139654699e-15]}
# jumping fist pos...
# 1/1 [==============================] - 0s 23ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999938, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [2.119489028729049e-10, 4.1256043720183655e-12, 0.9999938011169434, 6.2180347413232084e-06]}
# 1/1 [==============================] - 0s 13ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.8435409449013562e-12, 2.609864546698759e-09, 1.0, 4.258195223294167e-14, 6.144571657040743e-11, 2.3630576662103664e-12]}
# jumping fist pos...
# 1/1 [==============================] - 0s 26ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999654, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [2.1107163239442173e-10, 3.1351748454311323e-12, 0.999996542930603, 3.4014126413239865e-06]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [4.1190254332357235e-12, 3.544622151352428e-09, 1.0, 8.323254737339914e-14, 1.8583033722929798e-10, 5.273199845529097e-12]}
# jumping fist pos...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999982, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [9.082631174939237e-11, 2.6857257737211704e-12, 0.9999982118606567, 1.8248234709972166e-06]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [2.632453066295226e-12, 3.006658477744395e-09, 1.0, 5.696312833317757e-14, 9.890611940566174e-11, 3.3155492240588558e-12]}
# jumping fist pos...
# 1/1 [==============================] - 0s 23ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99998343, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [8.522917371855954e-10, 1.9299310413667392e-12, 0.9999834299087524, 1.6623673218418844e-05]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [2.983438149306572e-12, 3.1445088755077677e-09, 1.0, 6.613726764598954e-14, 1.0933427774251214e-10, 3.9355476343094775e-12]}
# jumping fist pos...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999964, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [8.052050237510044e-13, 6.344556634620482e-14, 0.9999996423721313, 3.332366986796842e-07]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999989, 'pass_general_tollerance': True, 'class': 'jump_though_first', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.1310916613049837e-11, 3.10506266032462e-07, 0.999998927116394, 2.230166940009326e-09, 6.729628694301937e-07, 1.5705825529011008e-09]}
# jumping fist pos...
# 1/1 [==============================] - 0s 27ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999917, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [2.643700417002265e-13, 2.006845210844599e-13, 0.9999991655349731, 8.450247150904033e-07]}
# 1/1 [==============================] - 0s 17ms/step
# {'argmax_index': 3, 'value_at_argmax': 0.99999964, 'pass_general_tollerance': True, 'class': 'jump_through_second', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [2.167399371089118e-09, 9.079478835438692e-10, 3.962018713110638e-09, 0.9999996423721313, 3.258449510212813e-07, 1.0070622721153333e-12]}
# jumping second pos...
# 1/1 [==============================] - 0s 22ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999995, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [2.1785435326375502e-13, 1.3372962947514472e-13, 0.9999995231628418, 4.481209145978937e-07]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 3, 'value_at_argmax': 0.9999994, 'pass_general_tollerance': True, 'class': 'jump_through_second', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [3.7036438360615875e-09, 1.3647728502874656e-09, 4.24403845400434e-09, 0.9999994039535522, 5.650976504512073e-07, 1.4284353864676969e-12]}
# jumping second pos...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999964, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [6.912099202466965e-14, 1.0158666036196376e-13, 0.9999996423721313, 3.001077004682884e-07]}
# 1/1 [==============================] - 0s 13ms/step
# {'argmax_index': 3, 'value_at_argmax': 0.99999976, 'pass_general_tollerance': True, 'class': 'jump_through_second', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.3379116703404748e-09, 5.727842644631664e-10, 4.59862725676885e-09, 0.9999997615814209, 2.558028029397974e-07, 9.916516392760588e-13]}
# jumping second pos...
# 1/1 [==============================] - 0s 27ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999976, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [1.9435817430295266e-13, 1.5073763092766923e-13, 0.9999997615814209, 2.8997234835514973e-07]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 3, 'value_at_argmax': 0.9999995, 'pass_general_tollerance': True, 'class': 'jump_through_second', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [3.587826480355716e-09, 1.9188948208181955e-09, 3.5331524372850254e-09, 0.9999995231628418, 5.271938903206319e-07, 1.1032117060161273e-12]}
# jumping second pos...
# 1/1 [==============================] - 0s 25ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999785, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [3.0065682582458564e-11, 1.0399438471822564e-12, 0.9999978542327881, 2.151336047973018e-06]}
# 1/1 [==============================] - 0s 13ms/step
# {'argmax_index': 1, 'value_at_argmax': 0.9999999, 'pass_general_tollerance': True, 'class': 'invalid', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.0132802152895692e-08, 0.9999998807907104, 8.874614110254697e-08, 8.711028317946734e-13, 1.268452787250851e-09, 1.231467011697518e-11]}
# do nothing nav...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999976, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [1.682213916776032e-11, 5.847200978612022e-13, 0.999997615814209, 2.4053797460510395e-06]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 5, 'value_at_argmax': 0.6243157, 'pass_general_tollerance': True, 'class': 'warp_to_dock', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [0.3655347526073456, 0.0010984812397509813, 0.0006863625603727996, 8.132440598274115e-06, 0.008356585167348385, 0.6243156790733337]}
# Warp To Dock pos...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999933, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [2.741195048727718e-10, 8.045965694918056e-13, 0.9999933242797852, 6.674983978882665e-06]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 4, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'no_action', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [7.678330193883198e-12, 6.936688203007524e-12, 8.683632979344935e-11, 7.770967758169434e-10, 1.0, 1.7985390737482176e-12]}
# do nothing nav...
# 1/1 [==============================] - 0s 26ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999974, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [2.146555433402142e-10, 3.875126673540119e-13, 0.9999973773956299, 2.564513124525547e-06]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 4, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'no_action', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [7.61227279127974e-12, 6.7739837177061e-12, 8.521769401248491e-11, 7.683319536155864e-10, 1.0, 1.821951877561956e-12]}
# do nothing nav...
# 1/1 [==============================] - 0s 24ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999987, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [6.619343961844493e-11, 2.923897831751815e-13, 0.9999986886978149, 1.2569794307637494e-06]}
# 1/1 [==============================] - 0s 13ms/step
# {'argmax_index': 4, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'no_action', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [9.642861162340033e-12, 8.843808498026906e-12, 1.0946406281409082e-10, 1.034262675503328e-09, 1.0, 2.334734402337224e-12]}
# do nothing nav...
# 1/1 [==============================] - 0s 25ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999964, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [3.8721175571465594e-11, 1.4808396479534802e-13, 0.9999996423721313, 3.123898864032526e-07]}
# 1/1 [==============================] - 0s 13ms/step
# {'argmax_index': 4, 'value_at_argmax': 1.0, 'pass_general_tollerance': True, 'class': 'no_action', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [1.1382890290068115e-11, 1.0561340864356783e-11, 1.3179581037636723e-10, 1.285051065558207e-09, 1.0, 2.7588027348701694e-12]}
# do nothing nav...
# 1/1 [==============================] - 0s 23ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.99999964, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [5.790808913115619e-13, 2.8438711075721296e-14, 0.9999996423721313, 4.014349315184518e-07]}
# 1/1 [==============================] - 0s 14ms/step
# {'argmax_index': 0, 'value_at_argmax': 0.98947036, 'pass_general_tollerance': True, 'class': 'dock_now', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [0.989470362663269, 0.0022226518485695124, 6.184964877320454e-05, 0.006263325922191143, 0.00031488933018408716, 0.001667023985646665]}
# Docking Now...
# 1/1 [==============================] - 0s 25ms/step
# {'argmax_index': 2, 'value_at_argmax': 0.9999994, 'pass_general_tollerance': True, 'class': 'in_flight', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [1.125197916611309e-12, 1.016872472185161e-13, 0.9999994039535522, 5.861517138328054e-07]}
# 1/1 [==============================] - 0s 15ms/step
# {'argmax_index': 0, 'value_at_argmax': 0.99003893, 'pass_general_tollerance': True, 'class': 'dock_now', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [0.9900389313697815, 0.002905634930357337, 4.513313251663931e-05, 0.005561376456171274, 0.00026739819440990686, 0.0011815006146207452]}
# Docking Now...
# 1/1 [==============================] - 0s 22ms/step
# {'argmax_index': 1, 'value_at_argmax': 0.9966769, 'pass_general_tollerance': True, 'class': 'connection_lost', 'classes': ['char_select', 'connection_lost', 'in_flight', 'in_hanger'], 'scores': [0.00029741457547061145, 0.9966769218444824, 0.00195710058324039, 0.0010685609886422753]}
# 1/1 [==============================] - 0s 15ms/step
# {'argmax_index': 1, 'value_at_argmax': 0.17956163, 'pass_general_tollerance': False, 'class': 'invalid', 'classes': ['dock_now', 'invalid', 'jump_though_first', 'jump_through_second', 'no_action', 'warp_to_dock'], 'scores': [0.17309904098510742, 0.17956162989139557, 0.1617645025253296, 0.14818477630615234, 0.16850964725017548, 0.1688804179430008]}
# do nothing state...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 65
#      63 time.sleep(0.1)
#      64 pyautogui.click(button='left')
# ---> 65 time.sleep(10)
#
# KeyboardInterrupt:

# %%
    img.save(f'O:\\source\\repos\\EVE-Online-Bot\\training_data\\unclass\\{uuid.uuid1()}.png')
    time.sleep(0.1)
    pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 25)
    time.sleep(0.1)
    pyautogui.click(button='left')
    time.sleep(0.1)
    pyautogui.moveTo(get_processed_cords(100, 100))
    time.sleep(0.1)
    pyautogui.click(button='left')
    time.sleep(10)

# %%
nav_point_xy = get_processed_cords(137, 378)

# %%
pyautogui.moveTo(nav_point_xy)
time.sleep(0.1)
pyautogui.click(button='right')
pyautogui.moveTo(get_processed_cords(10, 10))

# %%
box_top_left = (102, 289)
box_bottom_right = (458, 658)
img = get_screen()
img.crop([box_top_left[0], box_top_left[1], box_bottom_right[0], box_bottom_right[1]])
id = uuid.uuid1()
img.save(rf'O:\source\repos\EVE-Online-Bot\training_data\unclass\{}')

# %%
time.sleep(0.1)
pyautogui.moveTo(nav_point_xy[0] + 50, nav_point_xy[1] + 25)
time.sleep(0.1)
pyautogui.click(button='left')
time.sleep(0.1)
pyautogui.moveTo(10, 10)
