# %%
from tqdm import tqdm
import json
from PIL import Image
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#https://github.com/dhaitz/mplcyberpunk
import mplcyberpunk

plt.style.use("cyberpunk")
plt.rcParams['figure.facecolor'] = '#0d1117'
plt.rcParams['axes.facecolor'] = '#0d1117'
plt.rcParams['savefig.facecolor'] = '#0d1117'

# %%
def mkdir_p(path):
    try:
        os.makedirs(path)
    except OSError as exc: # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else: raise
        
def copy(source, destination):
    with open(source, 'rb') as file:
        myFile = file.read()
    with open(destination, 'wb') as file:
        file.write(myFile)

# %%
lines = ''
root_dir = '\\\\databrick\\N\\eve_logs'
#root_dir = "O:\\log_dir\\eve_miner"
with open(f"{root_dir}\\RedComputer_Main_UI.py_2023-04-12_19-12-32_020699.log") as f:
    lines = f.readlines()

# %%
clsf_name = 'game_state'

clsf_lines = []
for line in tqdm(lines):
    if f"'clsf': '{clsf_name}'" in line:
        index = line.find('{')
        clsf_lines.append(json.loads(line[index:-1].replace("'", '"').replace('UUID("', '"').replace('")', '"').replace("True", '1').replace("False", '0')))
df = pd.DataFrame(clsf_lines)
df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 49/49 [00:00<?, ?it/s]
#     argmax_index  value_at_argmax  pass_general_tollerance      class  \
# 0              2         0.951920                        1  in_flight
# 1              2         0.811536                        1  in_flight
# 2              2         0.771351                        1  in_flight
# 3              2         0.904466                        1  in_flight
# 4              2         0.978209                        1  in_flight
# 5              2         0.910033                        1  in_flight
# 6              2         0.937768                        1  in_flight
# 7              2         0.943887                        1  in_flight
# 8              2         0.823634                        1  in_flight
# 9              2         0.798180                        1  in_flight
# 10             2         0.764725                        1  in_flight
#
#                                               classes  \
# 0   [char_select, connection_lost, in_flight, in_h...
# 1   [char_select, connection_lost, in_flight, in_h...
# 2   [char_select, connection_lost, in_flight, in_h...
# 3   [char_select, connection_lost, in_flight, in_h...
# 4   [char_select, connection_lost, in_flight, in_h...
# 5   [char_select, connection_lost, in_flight, in_h...
# 6   [char_select, connection_lost, in_flight, in_h...
# 7   [char_select, connection_lost, in_flight, in_h...
# 8   [char_select, connection_lost, in_flight, in_h...
# 9   [char_select, connection_lost, in_flight, in_h...
# 10  [char_select, connection_lost, in_flight, in_h...
#
#                                                scores  \
# 0   [9.052529836850454e-10, 5.495228272422992e-09,...
# 1   [1.153206419246544e-09, 1.5395160701814348e-08...
# 2   [9.710825032982484e-09, 1.675481442475757e-08,...
# 3   [5.90820237178491e-09, 9.13040487660055e-09, 0...
# 4   [1.1294786217419528e-09, 4.877037884654101e-09...
# 5   [2.3183681641114617e-09, 5.539434688728306e-09...
# 6   [6.545422537307388e-10, 7.764453968661655e-09,...
# 7   [4.4771852891756225e-09, 5.103099720571436e-09...
# 8   [4.125221053641326e-09, 7.3461512428707465e-09...
# 9   [4.671767861452736e-09, 1.3223637296277957e-08...
# 10  [8.120380812215444e-09, 1.4146093185729569e-08...
#
#                                       id  image_saved        clsf
# 0   85351b3c-d987-11ed-8cf0-2cf05d9fe8eb            1  game_state
# 1   8c104d96-d987-11ed-b66f-2cf05d9fe8eb            1  game_state
# 2   9345fb07-d987-11ed-ae14-2cf05d9fe8eb            1  game_state
# 3   9a1c6ec2-d987-11ed-905a-2cf05d9fe8eb            1  game_state
# 4   a0ebcad5-d987-11ed-be70-2cf05d9fe8eb            1  game_state
# 5   a7c2b9be-d987-11ed-8910-2cf05d9fe8eb            1  game_state
# 6   ae903061-d987-11ed-a004-2cf05d9fe8eb            1  game_state
# 7   b5612e79-d987-11ed-95f9-2cf05d9fe8eb            1  game_state
# 8   bc2e044c-d987-11ed-a6c8-2cf05d9fe8eb            1  game_state
# 9   c2fd3df1-d987-11ed-b2e1-2cf05d9fe8eb            1  game_state
# 10  c9d284b5-d987-11ed-b9bb-2cf05d9fe8eb            1  game_state

# %%
source = f'\\\\databrick\\N\\eve_logs\\{clsf_name}'
dest = r'O:\eve_models\training_data\unclass'
for i in df.index:
    this_source = f"{source}\\{df.loc[i, 'id']}.png"
    this_dest = f"{dest}\\{df.loc[i, 'id']}.png"
    copy(this_source, this_dest)
